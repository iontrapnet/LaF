// %%
qt=require('qt');
// Out:
// { QBrush: [Function: QBrush],
//   QColor: [Function: QColor],
//   QFont: [Function: QFont],
//   QImage: [Function: QImage],
//   QListWidgetItem: [Function: QListWidgetItem],
//   QMatrix: [Function: QMatrix],
//   QModelIndex: [Function: QModelIndex],
//   QPainter: [Function: QPainter],
//   QPainterPath: [Function: QPainterPath],
//   QPalette: [Function: QPalette],
//   QPen: [Function: QPen],
//   QPixmap: [Function: QPixmap],
//   QPoint: [Function: QPoint],
//   QPointF: [Function: QPointF],
//   QPrinter: [Function: QPrinter],
//   QRect: [Function: QRect],
//   QSize: [Function: QSize],
//   QTableWidgetItem: [Function: QTableWidgetItem],
//   QTreeWidgetItem: [Function: QTreeWidgetItem],
//   QVariant: [Function: QVariant],
//   QCalendarWidget: [Function: QCalendarWidget],
//   QCheckBox: [Function: QCheckBox],
//   QComboBox: [Function: QComboBox],
//   QDateEdit: [Function: QDateEdit],
//   QDateTimeEdit: [Function: QDateTimeEdit],
//   QDial: [Function: QDial],
// ...

// %%
app = new qt.QApplication();
// Out:
// {}

// %%
win = new qt.QMainWindow();
// Out:
// [object QMainWindow]

// %%
win.show();
// Out:
// undefined

// %%
setInterval(app.processEvents,0);
// Out:
// { ontimeout: [Function] }

// %%
process.version
// Out:
// 'v0.8.25'
